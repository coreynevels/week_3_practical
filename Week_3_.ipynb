# %% [markdown]
# # **ggplot2**

# %% [markdown]
# **Question 1**
#
# Provide at least two methods to view the number of of rows and the number of columsn in the mpg dataset

# %%
nrow(mpg)
ncol(mpg)
# Out:
# [1] 234
# [1] 11

# %%
dim(mpg)
# Out:
# [1] 234  11

# %% [markdown]
# **Question 2**
#
# Run the following code:
#
# ggplot(data = mpg) +
# geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
#
# What is wrong with the code.
# Fix it so that the plot is displayed correctly.

# %%
ggplot(mpg) + geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %% [markdown]
# **Question 3**
#
# Change the code below so that
#
# mpg$class_numeric will be of type integer (int) rather than double (dbl)
# mpg$class_numeric = sapply(mpg$class, convert_class_int, USE.NAMES = FALSE)
#
# Inspect the result to make sure your solution worked

# %%
convert_class_int <- function(x) {
  if (x == "2seater") {
    1
  }else if (x == "compact"){
    2
  }else if (x == "subcompact"){
    3
  }else if(x == "midsize" ){
    4
  }else if(x == "midsize"){
    5
  }else if(x == "suv"){
    6
  }else if(x == "minivan"){
    7
  }else if(x == "pickup"){
    8
  }else{
    # Used for defensive programming purposes
    stop("value passed not recognized")
  }
}

# %%
mpg$class_numeric = as.integer(sapply(mpg$class, convert_class_int, USE.NAMES = FALSE))

# %%
(mpg)
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 21  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 22  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 23  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 28  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 205 toyota       toyota tacoma 4wd  3.4   1999 6   auto(l4)   4   15  19  r
# 206 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 207 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 208 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 209 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 210 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 211 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 212 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 214 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 215 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 217 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 218 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 219 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 220 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 221 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 222 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 223 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 224 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 225 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 226 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 227 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 228 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 229 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 230 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 231 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 232 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 233 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 234 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class      class_numeric
# 1   compact    2
# 2   compact    2
# 3   compact    2
# 4   compact    2
# 5   compact    2
# 6   compact    2
# 7   compact    2
# 8   compact    2
# 9   compact    2
# 10  compact    2
# 11  compact    2
# 12  compact    2
# 13  compact    2
# 14  compact    2
# 15  compact    2
# 16  midsize    4
# 17  midsize    4
# 18  midsize    4
# 19  suv        6
# 20  suv        6
# 21  suv        6
# 22  suv        6
# 23  suv        6
# 24  2seater    1
# 25  2seater    1
# 26  2seater    1
# 27  2seater    1
# 28  2seater    1
# 29  suv        6
# 30  suv        6
# ⋮   ⋮          ⋮
# 205 pickup     8
# 206 pickup     8
# 207 pickup     8
# 208 compact    2
# 209 compact    2
# 210 compact    2
# 211 compact    2
# 212 compact    2
# 213 compact    2
# 214 compact    2
# 215 compact    2
# 216 compact    2
# 217 compact    2
# 218 compact    2
# 219 compact    2
# 220 compact    2
# 221 compact    2
# 222 subcompact 3
# 223 subcompact 3
# 224 subcompact 3
# 225 subcompact 3
# 226 subcompact 3
# 227 subcompact 3
# 228 midsize    4
# 229 midsize    4
# 230 midsize    4
# 231 midsize    4
# 232 midsize    4
# 233 midsize    4
# 234 midsize    4

# %% [markdown]
# **Question 4**

# %% [markdown]
# Use a scatter plot to plot the variable cty (x-axis) and hwy (y-axis) of the mpg dataset
#
# Add another geom that shows the liner regression between x and y
#
# The method for computing linear regression should be a linear model lm instead of the default (loess)
#
# Set the line color to red
#
# color the points by class
#
# set the points size to 6

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = cty, y = hwy))
# Out:
# plot without title

# %%
ggplot(mpg, aes(cty,hwy))+
geom_point(aes(cty,hwy, color=class), size=6)+
geom_smooth(aes(), color="red", method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# outside of aes () apply to the whole graph, inside aes() applies to specific things

# %% [markdown]
# **Question 5**
#
# You noticed in the previous plot that there exist in the dataset subcompacts that has a city fuel consumption of 15 miles per gallon.
#
# Extract the manufacturer and model of these subcompacts
#
# results should only have these columnsa

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)

# %%
subcompacts_data <- mpg%>%
filter(class == "subcompact")%>%
filter(cty == "15")%>%
select("manufacturer", "model")

subcompacts_data
# Out:
#   manufacturer model
# 1 ford         mustang
# 2 ford         mustang
# 3 ford         mustang
# 4 ford         mustang

# %% [markdown]
# # another way to do Question 5

# %%
sub_15 <- subset(mpg, cty == 15 & class == "subcompact")
sub_15
# Out:
#   manufacturer model   displ year cyl trans      drv cty hwy fl class
# 1 ford         mustang 4.6   1999 8   auto(l4)   r   15  21  r  subcompact
# 2 ford         mustang 4.6   1999 8   manual(m5) r   15  22  r  subcompact
# 3 ford         mustang 4.6   2008 8   manual(m5) r   15  23  r  subcompact
# 4 ford         mustang 4.6   2008 8   auto(l5)   r   15  22  r  subcompact
#   class_numeric
# 1 3
# 2 3
# 3 3
# 4 3

# %% [markdown]
# # only show manufacturer and model rows of these subresults

# %%
select(sub_15, c("manufacturer", "model"))
# Out:
#   manufacturer model
# 1 ford         mustang
# 2 ford         mustang
# 3 ford         mustang
# 4 ford         mustang

# %% [markdown]
# **Question 6**
#
# The following generates a warning
#
# ggplot(data = mpg) +
# geom_point(mapping = aes(x = displ, y = hwy, shape = class))
#
# How can you fix that the code so all classes are displayed
#
# Hint: you can manually specify your own values for the shapes to use using scale_shape_manual geom. You can select any of the following shapes

# %%
ggplot(data = mpg) + 
scale_shape_manual(values = c(1,2,3,4,5,6,7))+
geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# plot without title

# %% [markdown]
# **Question 7**
#
# Given the following two vectors
#
# x <- c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235)
# y <- c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4)
#
# Combine the two vectors into a data frame called sizeMass
#
# Name the columns containing the vectors x and y as size and mass respectively
# Use the code below to plot the data
#
# If you followed the above instructions the code should work without modification
#
# ggplot(sizeMass, aes(size, mass)) +
#   geom_point() +
#   geom_smooth(method = "lm", color = "red", se = FALSE)

# %%
x<-c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235)
y<-c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4)

# %%
sizeMass <- data.frame(x,y)
colnames(sizeMass)=c("size","mass")
sizeMass
# Out:
#    size     mass
# 1     3.385   44.50
# 2     0.480   15.50
# 3     1.350    8.10
# 4   465.000  423.00
# 5    36.330  119.50
# 6    27.660  115.00
# 7    14.830   98.20
# 8     1.040    5.50
# 9     4.190   58.00
# 10    0.425    6.40
# 11    0.101    4.00
# 12    0.920    5.70
# 13    1.000    6.60
# 14    0.005    0.14
# 15    0.060    1.00
# 16    3.500   10.80
# 17    2.000   12.30
# 18    1.700    6.30
# 19 2547.000 4603.00
# 20    0.023    0.30
# 21  187.100  419.00
# 22  521.000  655.00
# 23    0.785    3.50
# 24   10.000  115.00
# 25    3.300   25.60
# 26    0.200    5.00
# 27    1.410   17.50
# 28  529.000  680.00
# 29  207.000  406.00
# 30   85.000  325.00
# ⋮  ⋮        ⋮
# 33 6654.000 5712.00
# 34    3.500    3.90
# 35    6.800  179.00
# 36   35.000   56.00
# 37    4.050   17.00
# 38    0.120    1.00
# 39    0.023    0.40
# 40    0.010    0.25
# 41    1.400   12.50
# 42  250.000  490.00
# 43    2.500   12.10
# 44   55.500  175.00
# 45  100.000  157.00
# 46   52.160  440.00
# 47   10.550  179.50
# 48    0.550    2.40
# 49   60.000   81.00
# 50    3.600   21.00
# 51    4.288   39.20
# 52    0.280    1.90
# 53    0.075    1.20
# 54    0.122    3.00
# 55    0.048    0.33
# 56  192.000  180.00
# 57    3.000   25.00
# 58  160.000  169.00
# 59    0.900    2.60
# 60    1.620   11.40
# 61    0.104    2.50
# 62    4.235   50.40

# %%
ggplot(sizeMass, aes(size, mass)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# **Question 8**
#
# In the above, the data is "squashed" because the data range varies substantially across observations. One way to fix this is by computing the log of the data. We will do that using two different approaches
#
# add two new columns called them size_log10 and mass_log that represent the log 10 values of the size and mass columns. Then, reuse the plotting code above by replacing size and mass with size_log10 and mass_log10 respectively
#
# Hint log10() can take as input a single value or a vector
# Use the scale_x_log10() and scale_y_log10() to set different scales for the x and y aesthetics
#
# Simply add these transforms to the initial snippet of code prior to plotting geom_point or geom_smooth

# %%
sizeMass_unsquash<-mutate(sizeMass,
                          size_log10 = log10(size),
                          mass_log10 = log10(mass))

# %%
ggplot(sizeMass_unsquash, aes(size_log10, mass_log10)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
